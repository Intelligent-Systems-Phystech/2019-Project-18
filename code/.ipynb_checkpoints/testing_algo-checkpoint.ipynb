# %%
from pls import pls_regression
from preprocessing import load_data
from plot_function import plot_res
import numpy as np

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as MSE

from qpfs import *

# %matplotlib inline

# %% [markdown]
# Загружаем тестовые данные.

# %%
 X_train, X_test, Y_train, Y_test = load_data()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-4-530b4b98ebd1> in <module>()
# ----> 1 X_train, X_test, Y_train, Y_test = load_data()
#
# ~/MIPT/strizhov/2019-Project-18/code/preprocessing.py in load_data()
#      23
#      24 def load_data():
# ---> 25     assert os.path.exists('../../data/ECoG_X_test.mat'), 'Data directory should contain train and test mats'
#      26
#      27     X_train = loadmat('../../data/ECoG_X_train.mat')
#
# AssertionError: Data directory should contain train and test mats

# %% [markdown]
# Запускаем алгоритм PLS.

# %%
predicted_PLS = pls_regression(50, X_train, X_test, Y_train, Y_test)
# Out:
# n_comps = 50; mae = 0.6914792601800265, mse = 0.944853769900984, r2 = 0.06452711843273777

# %% [markdown]
# Строим график результатов.

# %%
plot_res(Y_test, predicted_PLS)

# %% [markdown]
# График предсказаний с помощью алгоритма PLS сильно осциллирует. При этом, особенно на последнем графике, общий рисунок повторен довольно точно - почти все пики на графике наблюдаемого движения предсказаны корректно.
#
# Теперь запустим алгоритм QPFS.

# %%
qpfs = QPFS()

qpfs.fit(X_train, Y_train)

# %% [markdown]
# Обучим обычную линейную регрессию на первых 100 выбранных признаках.

# %%
feature_weights = qpfs.zx
k = 100

active_index = feature_weights.argsort()[::-1][:k]

lr = LinearRegression()
lr.fit(X_train[:, active_index], Y_train)
predicted_QPFS = lr.predict(X_test[:, active_index])
print("MSE =", MSE(predicted_QPFS, Y_test))
# Out:
# MSE = 0.9169826471872279

# %%
plot_res(Y_test, predicted_QPFS, '../doc/pictures/qpfs_results.pdf')

# %% [markdown]
# MSE получилось немного меньше, чем с помощью алгоритма PLS. График все также сильно осциллирует, и все также на некоторых координатах у алгоритма получается хорошо предсказать пики наблюдаемого движения.
