# %%
from pls import pls_regression, plot_res
from preprocessing import load_data

import numpy as np
# %matplotlib inline

# %%
 X_train, X_test, Y_train, Y_test = load_data()

# %%
predicted = pls_regression(50, X_train, X_test, Y_train, Y_test)
# Out:
# n_comps = 50; mae = 0.6914792601800265, mse = 0.944853769900984, r2 = 0.06452711843273777

# %%
plot_res(Y_test, predicted, None)
